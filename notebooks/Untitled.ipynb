# %%
import pandas as pd
import csv

df = pd.read_csv(r"C:\Users\HP\OneDrive\Desktop\DATA\zomato-market-intelligence-dashboard\data\zomato_feature_engineered.csv", engine="python")
df.to_csv(r"C:\Users\HP\OneDrive\Desktop\DATA\zomato-market-intelligence-dashboard\data\clean.csv", index=False,quoting=csv.QUOTE_ALL)
